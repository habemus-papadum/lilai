# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import sys

# Stream httpx/httpcore debug logging into the notebook output
formatter = logging.Formatter("%(asctime)s [%(levelname)s] %(name)s: %(message)s")

for logger_name in ("httpx", "httpcore"):
    logger = logging.getLogger(logger_name)
    logger.setLevel(logging.DEBUG)
    if not any(getattr(handler, "name", "") == "httpx_debug" for handler in logger.handlers):
        handler = logging.StreamHandler(sys.stdout)
        handler.name = "httpx_debug"
        handler.setLevel(logging.DEBUG)
        handler.setFormatter(formatter)
        logger.addHandler(handler)

# %%
import atexit
from openai import OpenAI
import httpx

body_logger = logging.getLogger("httpx.body")
body_logger.setLevel(logging.DEBUG)

def log_post_payload(request: httpx.Request) -> None:
    if request.method.upper() != "POST":
        return
    content = request.content
    if not content:
        return
    try:
        payload = content.decode()
    except UnicodeDecodeError:
        payload = repr(content)
    body_logger.debug("POST %s payload: %s", request.url, payload)

http_client = httpx.Client(event_hooks={"request": [log_post_payload]})
atexit.register(http_client.close)
client = OpenAI(http_client=http_client)

# %%
m = client.models.list()
# Out:
# 2025-10-05 21:11:21,263 [DEBUG] httpcore.connection: connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-10-05 21:11:21,280 [DEBUG] httpcore.connection: connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x114c28560>
# 2025-10-05 21:11:21,280 [DEBUG] httpcore.connection: start_tls.started ssl_context=<ssl.SSLContext object at 0x114382950> server_hostname='api.openai.com' timeout=5.0
# 2025-10-05 21:11:21,293 [DEBUG] httpcore.connection: start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x114b7ce90>
# 2025-10-05 21:11:21,294 [DEBUG] httpcore.http11: send_request_headers.started request=<Request [b'GET']>
# 2025-10-05 21:11:21,294 [DEBUG] httpcore.http11: send_request_headers.complete
# 2025-10-05 21:11:21,295 [DEBUG] httpcore.http11: send_request_body.started request=<Request [b'GET']>
# 2025-10-05 21:11:21,295 [DEBUG] httpcore.http11: send_request_body.complete
# 2025-10-05 21:11:21,295 [DEBUG] httpcore.http11: receive_response_headers.started request=<Request [b'GET']>
# 2025-10-05 21:11:21,721 [DEBUG] httpcore.http11: receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Mon, 06 Oct 2025 01:11:21 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'openai-version', b'2020-10-01'), (b'x-request-id', b'8136fb5890e2f90b89afd52c41059d99'), (b'openai-processing-ms', b'269'), (b'x-envoy-upstream-service-time', b'272'), (b'x-openai-proxy-wasm', b'v0.1'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=HFSwiIxFJtAr7JKvhQpMvDcRkuekYXfweuqR.I4dux8-1759713081-1.0.1.1-vEFxOSUD2U0nji2NtxMd7baj5n8NwRpVX3ypUo5TRq40nS9qsUiPotvXtGMGfmxjK7fnwLSWrhdc_Uu7CNTuydOaIUlyoLK9nRkLacS21AU; path=/; expires=Mon, 06-Oct-25 01:41:21 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=9.g7xW6qpbLEoQ8FHIunEUh.jlYBNyi1i0c3kOu2M5s-1759713081744-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'98a148c64ab08f75-BOS'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-10-05 21:11:21,723 [INFO] httpx: HTTP Request: GET https://api.openai.com/v1/models "HTTP/1.1 200 OK"
# 2025-10-05 21:11:21,723 [DEBUG] httpcore.http11: receive_response_body.started request=<Request [b'GET']>
# 2025-10-05 21:11:21,724 [DEBUG] httpcore.http11: receive_response_body.complete
# 2025-10-05 21:11:21,725 [DEBUG] httpcore.http11: response_closed.started
# 2025-10-05 21:11:21,725 [DEBUG] httpcore.http11: response_closed.complete

# %%
from interactive_json_tree import JSON
JSON(m.model_dump())
# Out:
# <style>
# #jt-e510c475 {
#   font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;
#   font-size: 13px; line-height: 1.45;
# }
# #jt-e510c475 summary {
#   cursor: pointer;
#   list-style: none;
#   display: inline-flex;
#   align-items: baseline;
#   gap: 0.25rem;
# }
# #jt-e510c475 summary::-webkit-details-marker { display: none; }
# #jt-e510c475 .jt-summary::before {
#   content: "▸";
#   display: inline-block;
#   width: 1em;
#   color: #94a3b8;
# }
# #jt-e510c475 details[open] > .jt-summary::before { content: "▾"; }
#
# #jt-e510c475 .jt-key   { color: #1f2937; }
# #jt-e510c475 .jt-punct { color: #94a3b8; }
# #jt-e510c475 .jt-str   { color: #059669; }
# #jt-e510c475 .jt-str-trunc { color: #dc2626; }
# #jt-e510c475 .jt-num   { color: #b45309; }
# #jt-e510c475 .jt-bool  { color: #2563eb; }
# #jt-e510c475 .jt-null  { color: #dc2626; }
# #jt-e510c475 .jt-more  { color: #94a3b8; }
# @media (prefers-color-scheme: dark) {
#   #jt-e510c475 .jt-key { color: #e5e7eb; }
#   #jt-e510c475 .jt-str-trunc { color: #f87171; }
#   #jt-e510c475 .jt-more { color: #64748b; }
# }
# </style>
# <div id="jt-e510c475" class="jt"><details class="jt-details" open style="margin-left:0.0rem"><summary class="jt-summary">{} Object <span class="jt-punct">(2)</span></summary><details class="jt-details" style="margin-left:0.5rem"><summary class="jt-summary"><span class="jt-key">"data"</span><span class="jt-punct">: </span>[] Array <span class="jt-punct">(93)</span></summary><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[0]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"gpt-4-0613"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"created"</span><span class="jt-punct">: </span><span class="jt-num">1686588896</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"object"</span><span class="jt-punct">: </span><span class="jt-str">"model"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"owned_by"</span><span class="jt-punct">: </span><span class="jt-str">"openai"</span></div></details><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[1]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"gpt-4"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"created"</span><span class="jt-punct">: </span><span class="jt-num">1687882411</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"object"</span><span class="jt-punct">: </span><span class="jt-str">"model"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"owned_by"</span><span class="jt-punct">: </span><span class="jt-str">"openai"</span></div></details><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[2]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"gpt-3.5-turbo"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"created"</span><span class="jt-punct">: </span><span class="jt-num">1677610602</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"object"</span><span class="jt-punct">: </span><span class="jt-str">"model"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"owned_by"</span><span class="jt-punct">: </span><span class="jt-str">"openai"</span></div></details><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[3]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"gpt-5-codex"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"created"</span><span class="jt-punct">: </span><span class="jt-num">1757527818</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"object"</span><span class="jt-punct">: </span><span class="jt-str">"model"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"owned_by"</span><span class="jt-punct">: </span><span class="jt-str">"system"</span></div></details><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[4]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem ...

# %%
from pydantic import BaseModel
class Item(BaseModel):
    name: str
    price: str

class Menu(BaseModel):
    restaurant: str
    items: list[Item]

# %%
response = client.responses.parse(
    model="gpt-5-nano",
    input="What appetizers available at Kava on shawmut ave ?",
    tools=[{"type": "web_search"}],
    text_format=Menu,
)
# Out:
# 2025-10-05 21:11:27,157 [DEBUG] httpx.body: POST https://api.openai.com/v1/responses payload: {"input":"What appetizers available at Kava on shawmut ave ?","model":"gpt-5-nano","text":{"format":{"type":"json_schema","strict":true,"name":"Menu","schema":{"$defs":{"Item":{"properties":{"name":{"title":"Name","type":"string"},"price":{"title":"Price","type":"string"}},"required":["name","price"],"title":"Item","type":"object","additionalProperties":false}},"properties":{"restaurant":{"title":"Restaurant","type":"string"},"items":{"items":{"$ref":"#/$defs/Item"},"title":"Items","type":"array"}},"required":["restaurant","items"],"title":"Menu","type":"object","additionalProperties":false}}},"tools":[{"type":"web_search"}]}
# 2025-10-05 21:11:27,157 [DEBUG] httpcore.connection: close.started
# 2025-10-05 21:11:27,158 [DEBUG] httpcore.connection: close.complete
# 2025-10-05 21:11:27,158 [DEBUG] httpcore.connection: connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-10-05 21:11:27,166 [DEBUG] httpcore.connection: connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x114c29280>
# 2025-10-05 21:11:27,166 [DEBUG] httpcore.connection: start_tls.started ssl_context=<ssl.SSLContext object at 0x114382950> server_hostname='api.openai.com' timeout=5.0
# 2025-10-05 21:11:27,174 [DEBUG] httpcore.connection: start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x114c29190>
# 2025-10-05 21:11:27,174 [DEBUG] httpcore.http11: send_request_headers.started request=<Request [b'POST']>
# 2025-10-05 21:11:27,174 [DEBUG] httpcore.http11: send_request_headers.complete
# 2025-10-05 21:11:27,175 [DEBUG] httpcore.http11: send_request_body.started request=<Request [b'POST']>
# 2025-10-05 21:11:27,175 [DEBUG] httpcore.http11: send_request_body.complete
# 2025-10-05 21:11:27,175 [DEBUG] httpcore.http11: receive_response_headers.started request=<Request [b'POST']>
# 2025-10-05 21:11:45,506 [DEBUG] httpcore.http11: receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Mon, 06 Oct 2025 01:11:45 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'x-ratelimit-limit-requests', b'30000'), (b'x-ratelimit-limit-tokens', b'180000000'), (b'x-ratelimit-remaining-requests', b'29999'), (b'x-ratelimit-remaining-tokens', b'179988141'), (b'x-ratelimit-reset-requests', b'2ms'), (b'x-ratelimit-reset-tokens', b'3ms'), (b'openai-version', b'2020-10-01'), (b'openai-organization', b'gresearchuk'), (b'openai-project', b'proj_B3WfcYF1KTvvTTP4S9KD8IjT'), (b'x-request-id', b'req_4f650e687e6405fad99828fd03b8c874'), (b'openai-processing-ms', b'18009'), (b'x-envoy-upstream-service-time', b'18012'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'98a148eb09723d15-BOS'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-10-05 21:11:45,509 [INFO] httpx: HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 2025-10-05 21:11:45,510 [DEBUG] httpcore.http11: receive_response_body.started request=<Request [b'POST']>
# 2025-10-05 21:11:45,511 [DEBUG] httpcore.http11: receive_response_body.complete
# 2025-10-05 21:11:45,511 [DEBUG] httpcore.http11: response_closed.started
# 2025-10-05 21:11:45,512 [DEBUG] httpcore.http11: response_closed.complete

# %%
JSON(response.model_dump())
# Out:
# <style>
# #jt-7ba6c196 {
#   font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;
#   font-size: 13px; line-height: 1.45;
# }
# #jt-7ba6c196 summary {
#   cursor: pointer;
#   list-style: none;
#   display: inline-flex;
#   align-items: baseline;
#   gap: 0.25rem;
# }
# #jt-7ba6c196 summary::-webkit-details-marker { display: none; }
# #jt-7ba6c196 .jt-summary::before {
#   content: "▸";
#   display: inline-block;
#   width: 1em;
#   color: #94a3b8;
# }
# #jt-7ba6c196 details[open] > .jt-summary::before { content: "▾"; }
#
# #jt-7ba6c196 .jt-key   { color: #1f2937; }
# #jt-7ba6c196 .jt-punct { color: #94a3b8; }
# #jt-7ba6c196 .jt-str   { color: #059669; }
# #jt-7ba6c196 .jt-str-trunc { color: #dc2626; }
# #jt-7ba6c196 .jt-num   { color: #b45309; }
# #jt-7ba6c196 .jt-bool  { color: #2563eb; }
# #jt-7ba6c196 .jt-null  { color: #dc2626; }
# #jt-7ba6c196 .jt-more  { color: #94a3b8; }
# @media (prefers-color-scheme: dark) {
#   #jt-7ba6c196 .jt-key { color: #e5e7eb; }
#   #jt-7ba6c196 .jt-str-trunc { color: #f87171; }
#   #jt-7ba6c196 .jt-more { color: #64748b; }
# }
# </style>
# <div id="jt-7ba6c196" class="jt"><details class="jt-details" open style="margin-left:0.0rem"><summary class="jt-summary">{} Object <span class="jt-punct">(32)</span></summary><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"resp_01defe4d050b8f980168e313ae17e081a3a20b9cd5827796b1"</span></div><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"created_at"</span><span class="jt-punct">: </span><span class="jt-num">1759712174.0</span></div><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"error"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"incomplete_details"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"instructions"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div><details class="jt-details" style="margin-left:0.5rem"><summary class="jt-summary"><span class="jt-key">"metadata"</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(0)</span></summary></details><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"model"</span><span class="jt-punct">: </span><span class="jt-str">"gpt-5-nano-2025-08-07"</span></div><div class="jt-leaf" style="margin-left:0.5rem"><span class="jt-key">"object"</span><span class="jt-punct">: </span><span class="jt-str">"response"</span></div><details class="jt-details" style="margin-left:0.5rem"><summary class="jt-summary"><span class="jt-key">"output"</span><span class="jt-punct">: </span>[] Array <span class="jt-punct">(6)</span></summary><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[0]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(6)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"rs_01defe4d050b8f980168e313aeb50881a38519b9d3348b9221"</span></div><details class="jt-details" style="margin-left:1.5rem"><summary class="jt-summary"><span class="jt-key">"summary"</span><span class="jt-punct">: </span>[] Array <span class="jt-punct">(0)</span></summary></details><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"type"</span><span class="jt-punct">: </span><span class="jt-str">"reasoning"</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"content"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"encrypted_content"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"status"</span><span class="jt-punct">: </span><span class="jt-null">null</span></div></details><details class="jt-details" style="margin-left:1.0rem"><summary class="jt-summary"><span class="jt-key">[1]</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(4)</span></summary><div class="jt-leaf" style="margin-left:1.5rem"><span class="jt-key">"id"</span><span class="jt-punct">: </span><span class="jt-str">"ws_01defe4d050b8f980168e313b0753881a3a2a2cae8dd96e76e"</span></div><details class="jt-details" style="margin-left:1.5rem"><summary class="jt-summary"><span class="jt-key">"action"</span><span class="jt-punct">: </span>{} Object <span class="jt-punct">(3)</span></summary><div class="jt-leaf" style="margin-left:2.0rem"><span class="jt-key">"query"</span><span class="jt-punct">: </span><span class="jt-str">"Kava Shawmut Ave appetizers"</span></div><div class="jt-leaf" style="margin-left:2.0rem"><span class="jt-key">"type"</span><span class="jt-punct">: </span><span class="jt-str">"search"</span></div><div class="jt-leaf" styl ...

# %% [markdown]
# TODO
# ----------
# - Streaming: log messages, replay, visualize
# - converations, other parameters
# - log api call -- using httpx logger
